# %% [markdown]
# # Module 1 Programming Assignment - Numbers and Types

# %% [markdown]
# ### 3.1 How many seconds are in an hour?

# %%
secs_per_min = 60
mins_per_hour = 60
print(secs_per_min * mins_per_hour)  # prints the number of seconds in an hour
# Out:
# 3600

# %% [markdown]
# ### 3.2 Assign the result from the previous task (seconds in an hour) to a variable called seconds_per_hour.

# %%
secs_per_min = 60
mins_per_hour = 60
secs_per_hour = secs_per_min * mins_per_hour

print(f"There are {secs_per_hour} seconds in an hour")
# Out:
# There are 3600 seconds in an hour

# %% [markdown]
# ### 3.3 How many seconds are in a day? Use your seconds_per_hour variable.

# %%
secs_per_min = 60
mins_per_hour = 60
secs_per_hour = secs_per_min * mins_per_hour

print(secs_per_hour * 24)
# Out:
# 86400

# %% [markdown]
# ### 3.4 Calculate seconds per day again, but this time save the result in a variable called seconds_per_day.

# %%
secs_per_min = 60
mins_per_hour = 60
secs_per_hour = secs_per_min * mins_per_hour
secs_per_day = secs_per_hour * 24
print(secs_per_day)
# Out:
# 86400

# %% [markdown]
# ### 3.5 Divide seconds_per_day by seconds_per_hour. Use floating-point (/) division.

# %%
secs_per_min = 60
mins_per_hour = 60
secs_per_hour = secs_per_min * mins_per_hour
secs_per_day = secs_per_hour * 24


print(secs_per_day / secs_per_hour)
# Out:
# 24.0

# %% [markdown]
# ### 3.6 Divide seconds_per_day by seconds_per_hour, using integer (//) division.

# %%
secs_per_min = 60
mins_per_hour = 60
secs_per_hour = secs_per_min * mins_per_hour
secs_per_day = secs_per_hour * 24


print(secs_per_day // secs_per_hour)
# Out:
# 24
